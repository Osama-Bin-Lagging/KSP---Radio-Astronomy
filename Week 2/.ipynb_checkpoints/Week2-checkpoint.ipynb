# %% [markdown]
# # A Near- Perfect Black Body

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
data = pd.read_csv('./COBE_CMB_data.txt', delimiter = ' ')
data
# Out:
#     frequency (Hz)  brightness (ergs/s/cm^2/sr/Hz)
# 0     3.447358e+10                    7.029472e-16
# 1     4.289696e+10                    1.025318e-15
# 2     5.132233e+10                    1.354405e-15
# 3     6.034453e+10                    1.690207e-15
# 4     6.876791e+10                    2.012578e-15
# 5     7.778013e+10                    2.314800e-15
# 6     8.560070e+10                    2.610307e-15
# 7     9.401010e+10                    2.885665e-15
# 8     1.024075e+11                    3.120727e-15
# 9     1.113938e+11                    3.335641e-15
# 10    1.197733e+11                    3.510258e-15
# 11    1.287336e+11                    3.637863e-15
# 12    1.359034e+11                    3.745320e-15
# 13    1.454466e+11                    3.832629e-15
# 14    1.543790e+11                    3.866209e-15
# 15    1.621157e+11                    3.879641e-15
# 16    1.710321e+11                    3.859493e-15
# 17    1.793517e+11                    3.832629e-15
# 18    1.876613e+11                    3.772185e-15
# 19    1.965617e+11                    3.698308e-15
# 20    2.054542e+11                    3.597567e-15
# 21    2.131610e+11                    3.510258e-15
# 22    2.220435e+11                    3.375937e-15
# 23    2.309279e+11                    3.248332e-15
# 24    2.392176e+11                    3.120727e-15
# 25    2.469104e+11                    2.986406e-15
# 26    2.551941e+11                    2.838653e-15
# 27    2.634837e+11                    2.711048e-15
# 28    2.711705e+11                    2.556579e-15
# 29    2.800510e+11                    2.415541e-15
# 30    2.895303e+11                    2.287936e-15
# 31    2.978140e+11                    2.140183e-15
# 32    3.060976e+11                    1.992430e-15
# 33    3.137964e+11                    1.878257e-15
# 34    3.226849e+11                    1.764084e-15
# 35    3.303777e+11                    1.629763e-15
# 36    3.398630e+11                    1.522306e-15
# 37    3.469710e+11                    1.421565e-15
# 38    3.558634e+11                    1.320824e-15
# 39    3.635602e+11                    1.199935e-15
# 40    3.718619e+11                    1.112627e-15
# 41    3.801655e+11                    1.032034e-15
# 42    3.890599e+11                    9.380091e-16
# 43    3.979604e+11                    8.641325e-16
# 44    4.056731e+11                    7.969719e-16
# 45    4.151704e+11                    7.298114e-16
# 46    4.240728e+11                    6.626508e-16
# 47    4.395064e+11                    5.551939e-16
# 48    4.567284e+11                    4.611692e-16
# 49    4.727668e+11                    3.872925e-16
# 50    4.899968e+11                    3.201320e-16
# 51    5.060391e+11                    2.596875e-16
# 52    5.232731e+11                    2.059590e-16
# 53    5.399182e+11                    1.723788e-16
# 54    5.571582e+11                    1.387985e-16
# 55    5.738034e+11                    1.052182e-16
# 56    5.910494e+11                    9.178609e-17

# %%
plt.plot(data['frequency (Hz)'], data['brightness (ergs/s/cm^2/sr/Hz)'] * 1e-3 )
plt.xlabel('Frequency (10^11 Hz)')
plt.ylabel('Brightness (10^-18 J/s/m^2/sr/Hz)')
plt.show()

# %%
planck_constant = 6.626e-34
speed_light = 3e8
boltsmann_constant = 1.38e-23

def blackbody_function(v, T):
    return 2* planck_constant * pow(v, 3)/( pow(speed_light, 2) * (np.exp(planck_constant * v/(boltsmann_constant * T)) - 1))

# %%
T, covarr = curve_fit(blackbody_function, data['frequency (Hz)'], data['brightness (ergs/s/cm^2/sr/Hz)'] * 1e-3)
T[0]
# Out:
# 2.740289273966668

# %% [markdown]
# #### The expansion of the Universe has stretched out the CMB radiation by around 1000 times, which makes it look much cooler. So instead of seeing the afterglow at 3000 degrees, we see it at just 3o above absolute zero, or 3 Kelvin (-270$^o$ C).

# %% [markdown]
# # Plotting the Galaxy Rotation Curve

# %%
import tarfile

with tarfile.open('galaxy_21cm_spectrum.tar.xz') as f:
    f.extractall('./spectral_data')

# %%
import os

directory = './spectral_data'

spectral_data = {}
for filename in os.scandir(directory):
    filepath = filename.path
    df = pd.read_csv(filepath, delimiter=' ')
    spectral_data[float(str(filename)[22:-10])] = df
    
print(spectral_data)
# Out:
# {5.11:      wavelngth (cm)  brightness
# 0         20.958084    2.091941
# 1         20.958168    4.483908
# 2         20.958252    0.731278
# 3         20.958336    8.048551
# 4         20.958420    1.009468
# ..              ...         ...
# 995       21.041664    7.712440
# 996       21.041748    6.901230
# 997       21.041832    9.163616
# 998       21.041916    1.568488
# 999       21.042000    7.425440
#
# [1000 rows x 2 columns], 5.62:      wavelngth (cm)  brightness
# 0         20.958084    5.890869
# 1         20.958168    6.942720
# 2         20.958252    9.498753
# 3         20.958336    0.156852
# 4         20.958420    2.934908
# ..              ...         ...
# 995       21.041664    8.019287
# 996       21.041748    2.603420
# 997       21.041832    2.694108
# 998       21.041916    1.221485
# 999       21.042000    8.528683
#
# [1000 rows x 2 columns], 1.38:      wavelngth (cm)  brightness
# 0         20.958084    8.247952
# 1         20.958168    8.697142
# 2         20.958252    2.938074
# 3         20.958336    3.424763
# 4         20.958420    3.186552
# ..              ...         ...
# 995       21.041664    8.795043
# 996       21.041748    1.167700
# 997       21.041832    3.390804
# 998       21.041916    1.756662
# 999       21.042000    9.314727
#
# [1000 rows x 2 columns], 6.5:      wavelngth (cm)  brightness
# 0         20.958084    2.031897
# 1         20.958168    0.178244
# 2         20.958252    3.464754
# 3         20.958336    3.460960
# 4         20.958420    0.433580
# ..              ...         ...
# 995       21.041664    6.496555
# 996       21.041748    1.348638
# 997       21.041832    1.749996
# 998       21.041916    5.113863
# 999       21.042000    6.135466
#
# [1000 rows x 2 columns], 2.72:      wavelngth (cm)  brightness
# 0         20.958084    8.628188
# 1         20.958168    0.362862
# 2         20.958252   10.015347
# 3         20.958336    4.278590
# 4         20.958420    3.492980
# ..              ...         ...
# 995       21.041664    4.473867
# 996       21.041748    2.726207
# 997       21.041832    6.086416
# 998       21.041916    5.308745
# 999       21.042000    1.770506
#
# [1000 rows x 2 columns], 0.69:      wavelngth (cm)  brightness
# 0         20.958084    5.814652
# 1         20.958168    7.580379
# 2         20.958252    3.548402
# 3         20.958336    7.931321
# 4         20.958420    8.254232
# ..              ...         ...
# 995       21.041664   10.419293
# 996       21.041748   10.056386
# 997       21.041832    8.339915
# 998       21.041916    7.940472
# 999       21.042000    1.074528
#
# [1000 rows x 2 columns], 6.06:      wavelngth (cm)  brightness
# 0         20.958084    6.454580
# 1         20.958168    1.774961
# 2         20.958252    5.150993
# 3         20.958336    6.597718
# 4         20.958420    8.035799
# ..              ...         ...
# 995       21.041664    3.099376
# 996       21.041748    4.509823
# 997       21.041832    9.532555
# 998       21.041916    4.556565
# 999       21.042000    5.121863
#
# [1000 rows x 2 columns], 4.54:      wavelngth (cm)  brightness
# 0         20.958084    2.899802
# 1         20.958168    5.722491
# 2         20.958252    5.593829
# 3         20.958336    6.508328
# 4         20.958420    8.822767
# ..              ...         ...
# 995       21.041664    3.491960
# 996       21.041748    3.902183
# 997       21.041832    8.916520
# 998       21.041916    7.300717
# 999       21.042000    0.453981
#
# [1000 rows x 2 columns], 3.35:      wavelngth (cm)  brightness
# 0         20.958084    9.224245
# 1         20.958168    1.063528
# 2         20.958252    4.240545
# 3         20.958336    6.482268
# 4         20.958420    5.212591
# ..              ...         ...
# 995       21.041664    3.272375
# 996       21.041748    7.291372
# 997       21.041832    5.039156
# 998       21.041916    3.324085
# 999       21.042000    8.936829
#
# [1000 rows x 2 columns], 6.87:      wavelngth (cm)  brightness
# 0         20.958084    8.351970
# 1         20.958168    7.557143
# 2         20.958252    7.266021
# 3         20.958336    7.096556
# 4         20.958420    5.895928
# ..              ...         ...
# 995       21.041664    2.832056
# 996       21.041748    2.225937
# 997       21.041832    9.072796
# 998       21.041916    6.120404
# 999       21.042000    7.465944
#
# [1000 rows x 2 columns], 2.06:      wavelngth (cm)  brightness
# 0         20.958084    2.763818
# 1         20.958168    3.673952
# 2         20.958252    6.694795
# 3         20.958336    3.653556
# 4         20.958420    9.071486
# ..              ...         ...
# 995       21.041664    6.671183
# 996       21.041748    5.701265
# 997       21.041832    0.563160
# 998       21.041916    1.507613
# 999       21.042000    2.696342
#
# [1000 rows x 2 columns], 3.96:      wavelngth (cm)  brightness
# 0         20.958084    3.942703
# 1         20.958168    1.279944
# 2         20.958252    7.767605
# 3         20.958336    4.984607
# 4         20.958420    0.768666
# ..              ...         ...
# 995       21.041664    3.489744
# 996       21.041748    2.905678
# 997       21.041832    5.655797
# 998       21.041916    9.319375
# 999       21.042000    5.386115
#
# [1000 rows x 2 columns]}

# %%
def gaussian(x, mean, std, amplitude):
    return amplitude * np.exp(-0.5 * ((x - mean) / std)**2)

# %%
c = 3e8
rest_freq = 1420.40575177e6

def fit_gaussian(xdata, ydata):
    initial_guess = [np.mean(xdata), np.std(xdata), np.max(xdata)]
    params, covariance = curve_fit(gaussian, xdata, ydata, p0=initial_guess)
    delta_freq = params[0] - rest_freq
    velocity = -delta_freq/rest_freq * c
    return params[0], velocity

# %%
velocity = []
central_freq = []
distance_list = []
for key in spectral_data.keys():
    distance_list.append(key)
    freq, vel_data = fit_gaussian(c/spectral_data[key]['wavelngth (cm)'] * 100, spectral_data[key]['brightness'])
    velocity.append(vel_data)
    
print(velocity)
# Out:
# [-1504402.6530591412, -1499376.4775986064, -1653216.3762510836, -1489323.5647057355, -1512948.6100201092, -1689427.9102281288, -1489333.3460158932, -1500399.2383555656, -1513466.2688718624, -1495360.7634172987, -1603928.3177736232, -1502415.2757735744]

# %%
plt.scatter(distance_list, velocity)
plt.xlabel('distance (kpc)')
plt.ylabel('Doppler velocity (10^6 m/s)')
plt.title('Galaxy Rotation Curve')
plt.show()

# %% [markdown]
# When studying other galaxies it is invariably found that the stellar rotational velocity remains constant, or "flat", with increasing distance away from the galactic center. This result is highly counterintuitive since, based on Newton's law of gravity, the rotational velocity would steadily decrease for stars further away from the galactic center. Analogously, inner planets within the Solar System travel more quickly about the Sun than do the outer planets (e.g. the Earth travels around the sun at about 100,000 km/hr while Saturn, which is further out, travels at only one third this speed). One way to speed up the outer planets would be to add more mass to the solar system, between the planets. By the same argument the flat galactic rotation curves seem to suggest that each galaxy is surrounded by significant amounts of dark matter. It has been postulated,and generally accepted, that the dark matter would have to be located in a massive, roughly spherical halo enshrouding each galaxy.
